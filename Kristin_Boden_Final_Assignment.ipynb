# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kristin Boden**
#
# Current Occupation: Engineer

# %% [markdown]
# *I am interested in Data Science because I have a history working with data as an engineer and think this is a career with a lot of potential.*

# %% [markdown]
# ### My code evaluates two times ten

# %%
2*10
# Out:
# 20

# %% [markdown]
# [Here is a link to CNN](https://www.cnn.com/world)
#
# |Hello|Hi|Ok|
# |---|---|---|
# |One|Two|Three|
# |Three|Two|One|
#
# 1. Numbered List 1
# 2. Numbered List 2
# 3. Numbered List 3
